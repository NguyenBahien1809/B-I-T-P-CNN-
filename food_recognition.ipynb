# %%
#mount với drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from keras.models import Sequential
from keras.layers import Convolution2D as Conv2D
from keras.layers import Flatten, MaxPooling2D
from keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
from keras.layers import Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# %%
batch_size = 1
img_size = (150, 150)
img_path = '/content/drive/MyDrive/DỮ LIỆU AI PHẦN BT CNN/món ăn/train_mon_an'

# %%
image_generator = ImageDataGenerator(
    rescale = 1./255,
    brightness_range = (0.8, 1.2),
    zoom_range= (0.9, 1.2),
    validation_split= 0.2)

train_dataset= image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'training')
validation_dataset = image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,  
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'validation')
# Out:
# Found 275 images belonging to 10 classes.
# Found 64 images belonging to 10 classes.

# %%
train_dataset.classes
print(train_dataset.class_indices)
# Out:
# {'banh beo': 0, 'banh cuon': 1, 'banh mi': 2, 'banh trang nuong': 3, 'banh xeo': 4, 'bun bo': 5, 'com suon': 6, 'goi cuon': 7, 'mi quang': 8, 'nem chua': 9}

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(512, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_15 (MaxPoolin  (None, 74, 74, 32)       0
#  g2D)
#
#  batch_normalization_12 (Bat  (None, 74, 74, 32)       128
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_16 (MaxPoolin  (None, 36, 36, 64)       0
#  g2D)
#
#  batch_normalization_13 (Bat  (None, 36, 36, 64)       256
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 34, 34, 128)       73856
#
#  max_pooling2d_17 (MaxPoolin  (None, 17, 17, 128)      0
#  g2D)
#
#  batch_normalization_14 (Bat  (None, 17, 17, 128)      512
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 15, 15, 256)       295168
#
#  max_pooling2d_18 (MaxPoolin  (None, 7, 7, 256)        0
#  g2D)
#
#  batch_normalization_15 (Bat  (None, 7, 7, 256)        1024
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 5, 5, 512)         1180160
#
#  max_pooling2d_19 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 128)               262272
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,834,058
# Trainable params: 1,833,098
# Non-trainable params: 960
# _________________________________________________________________

# %%
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model.compile(optimizer = opt, loss ='binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,batch_size=65,epochs=20,validation_data=validation_dataset)
# Out:
# Epoch 1/20
# 275/275 [==============================] - 97s 347ms/step - loss: 0.3572 - accuracy: 0.2000 - val_loss: 0.3462 - val_accuracy: 0.0938
# Epoch 2/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.2739 - accuracy: 0.3891 - val_loss: 0.3452 - val_accuracy: 0.1875
# Epoch 3/20
# 275/275 [==============================] - 4s 15ms/step - loss: 0.2040 - accuracy: 0.6036 - val_loss: 0.3540 - val_accuracy: 0.2812
# Epoch 4/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.1467 - accuracy: 0.7818 - val_loss: 0.3787 - val_accuracy: 0.2812
# Epoch 5/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.1036 - accuracy: 0.8800 - val_loss: 0.3284 - val_accuracy: 0.3594
# Epoch 6/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0654 - accuracy: 0.9709 - val_loss: 0.3893 - val_accuracy: 0.2656
# Epoch 7/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0421 - accuracy: 0.9927 - val_loss: 0.4313 - val_accuracy: 0.3750
# Epoch 8/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0302 - accuracy: 0.9964 - val_loss: 0.3989 - val_accuracy: 0.3125
# Epoch 9/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0301 - accuracy: 0.9891 - val_loss: 0.4067 - val_accuracy: 0.3750
# Epoch 10/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.3438
# Epoch 11/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4197 - val_accuracy: 0.3750
# Epoch 12/20
# 275/275 [==============================] - 4s 15ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.4296 - val_accuracy: 0.3281
# Epoch 13/20
# 275/275 [==============================] - 4s 15ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.3750
# Epoch 14/20
# 275/275 [==============================] - 5s 19ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4248 - val_accuracy: 0.3594
# Epoch 15/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.3438
# Epoch 16/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.3750
# Epoch 17/20
# 275/275 [==============================] - 4s 14ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.3281
# Epoch 18/20
# 275/275 [==============================] - 4s 15ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 0.3750
# Epoch 19/20
# 275/275 [==============================] - 4s 15ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.3438
# Epoch 20/20
# 275/275 [==============================] - 5s 17ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4295 - val_accuracy: 0.4062

# %%
filename = "/content/drive/MyDrive/DỮ LIỆU AI PHẦN BT CNN/món ăn/banh_cuon.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("BÁNH BÈO ")
if(test==1):
    print("BÁNH CUỐN")
if(test ==2):
    print("BÁNH MÌ")
if(test==3):
    print("BÁNH TRÁNG NƯỚNG")
if(test ==4):
    print("BÁNH XÈO")
if(test==5):
    print("BÚN BÒ ")
if(test ==6):
    print("CƠM XƯỜN")
if(test==7):
    print("GỎI CUỐN")
if(test ==8):
    print("MÌ QUẢNG ")
if(test==9):
    print("NEM CHUA")
# Out:
# BÁNH CUỐN

# %%
filename = "/content/drive/MyDrive/DỮ LIỆU AI PHẦN BT CNN/món ăn/test_banh_mi.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("BÁNH BÈO ")
if(test==1):
    print("BÁNH CUỐN")
if(test ==2):
    print("BÁNH MÌ")
if(test==3):
    print("BÁNH TRÁNG NƯỚNG")
if(test ==4):
    print("BÁNH XÈO")
if(test==5):
    print("BÚN BÒ ")
if(test ==6):
    print("CƠM XƯỜN")
if(test==7):
    print("GỎI CUỐN")
if(test ==8):
    print("MÌ QUẢNG ")
if(test==9):
    print("NEM CHUA")
# Out:
# BÁNH MÌ

# %%
filename = "/content/drive/MyDrive/DỮ LIỆU AI PHẦN BT CNN/món ăn/test_banh_beo.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("BÁNH BÈO ")
if(test==1):
    print("BÁNH CUỐN")
if(test ==2):
    print("BÁNH MÌ")
if(test==3):
    print("BÁNH TRÁNG NƯỚNG")
if(test ==4):
    print("BÁNH XÈO")
if(test==5):
    print("BÚN BÒ ")
if(test ==6):
    print("CƠM XƯỜN")
if(test==7):
    print("GỎI CUỐN")
if(test ==8):
    print("MÌ QUẢNG ")
if(test==9):
    print("NEM CHUA")
# Out:
# BÁNH BÈO
